# %%
# importing the hand written digit dataset
from sklearn import datasets

# digit contain the dataset
digits = datasets.load_digits()

# dir function use to display the attributes of the dataset
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
# outputting the picture value as a series of numbers
print(digits.images[0])
# Out:
# [[ 0.  0.  5. 13.  9.  1.  0.  0.]
#  [ 0.  0. 13. 15. 10. 15.  5.  0.]
#  [ 0.  3. 15.  2.  0. 11.  8.  0.]
#  [ 0.  4. 12.  0.  0.  8.  8.  0.]
#  [ 0.  5.  8.  0.  0.  9.  8.  0.]
#  [ 0.  4. 11.  0.  1. 12.  7.  0.]
#  [ 0.  2. 14.  5. 10. 12.  0.  0.]
#  [ 0.  0.  6. 13. 10.  0.  0.  0.]]

# %%
# importing the matplotlib libraries pyplot function
import matplotlib.pyplot as plt
# defining the function plot_multi

def plot_multi(i):
	nplots = 16
	fig = plt.figure(figsize=(15, 15))
	for j in range(nplots):
		plt.subplot(4, 4, j+1)
		plt.imshow(digits.images[i+j], cmap='binary')
		plt.title(digits.target[i+j])
		plt.axis('off')
	# printing the each digits in the dataset.
	plt.show()

	plot_multi(0)

# %%
# converting the 2 dimensional array to one dimensional array
y = digits.target
x = digits.images.reshape((len(digits.images), -1))

# gives the shape of the data
x.shape
# Out:
# (1797, 64)

# %%
# printing the one-dimensional array's values
x[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
# Normalize the data
x = x / 16.0

# importing the train_test_split function
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# importing the MLP classifier from sklearn
from sklearn.neural_network import MLPClassifier

# calling the MLP classifier with specific parameters
mlp = MLPClassifier(hidden_layer_sizes=(15,),
					activation='logistic',
					alpha=1e-4, solver='sgd',
					tol=1e-4, random_state=1,
					learning_rate_init=.1,
					verbose=True)

# %%
mlp.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 2.32801985
# Iteration 2, loss = 2.27079263
# Iteration 3, loss = 2.22973161
# Iteration 4, loss = 2.15144762
# Iteration 5, loss = 2.04867431
# Iteration 6, loss = 1.91083547
# Iteration 7, loss = 1.73143567
# Iteration 8, loss = 1.53984107
# Iteration 9, loss = 1.35374203
# Iteration 10, loss = 1.18539817
# Iteration 11, loss = 1.04016807
# Iteration 12, loss = 0.91940807
# Iteration 13, loss = 0.81785100
# Iteration 14, loss = 0.73143734
# Iteration 15, loss = 0.66298955
# Iteration 16, loss = 0.60379077
# Iteration 17, loss = 0.55140735
# Iteration 18, loss = 0.50840177
# Iteration 19, loss = 0.47077773
# Iteration 20, loss = 0.43938641
# Iteration 21, loss = 0.41089165
# Iteration 22, loss = 0.38697566
# Iteration 23, loss = 0.36361753
# Iteration 24, loss = 0.34414913
# Iteration 25, loss = 0.32721487
# Iteration 26, loss = 0.31086864
# Iteration 27, loss = 0.29745120
# Iteration 28, loss = 0.28395027
# Iteration 29, loss = 0.27361750
# Iteration 30, loss = 0.26347781
# Iteration 31, loss = 0.25410898
# Iteration 32, loss = 0.24451170
# Iteration 33, loss = 0.23580084
# Iteration 34, loss = 0.22858113
# Iteration 35, loss = 0.22265620
# Iteration 36, loss = 0.21689076
# Iteration 37, loss = 0.20757975
# Iteration 38, loss = 0.20282627
# Iteration 39, loss = 0.19791872
# Iteration 40, loss = 0.19250599
# Iteration 41, loss = 0.18776450
# Iteration 42, loss = 0.18299826
# Iteration 43, loss = 0.17943659
# Iteration 44, loss = 0.17517175
# Iteration 45, loss = 0.17127227
# Iteration 46, loss = 0.16817818
# Iteration 47, loss = 0.16404953
# Iteration 48, loss = 0.16090267
# Iteration 49, loss = 0.15750934
# Iteration 50, loss = 0.15444611
# Iteration 136, loss = 0.06045384
# Iteration 137, loss = 0.06009470
# Iteration 138, loss = 0.05963388
# Iteration 139, loss = 0.05932957
# Iteration 140, loss = 0.05894391
# Iteration 141, loss = 0.05831212
# Iteration 142, loss = 0.05780527
# Iteration 143, loss = 0.05750433
# Iteration 144, loss = 0.05694678
# Iteration 145, loss = 0.05611205
# Iteration 146, loss = 0.05586466
# Iteration 147, loss = 0.05545643
# Iteration 148, loss = 0.05510125
# Iteration 149, loss = 0.05456902
# Iteration 150, loss = 0.05513205
# Iteration 151, loss = 0.05448513
# Iteration 152, loss = 0.05367177
# Iteration 153, loss = 0.05323544
# Iteration 154, loss = 0.05271287
# Iteration 155, loss = 0.05267755
# Iteration 156, loss = 0.05227496
# Iteration 157, loss = 0.05180611
# Iteration 158, loss = 0.05169563
# Iteration 159, loss = 0.05112021
# Iteration 160, loss = 0.05100991
# Iteration 161, loss = 0.05047054
# Iteration 162, loss = 0.05018348
# Iteration 163, loss = 0.05001021
# Iteration 164, loss = 0.04954890
# Iteration 165, loss = 0.04943824
# Iteration 166, loss = 0.04872602
# Iteration 167, loss = 0.04867631
# Iteration 168, loss = 0.04822860
# Iteration 169, loss = 0.04828962
# Iteration 170, loss = 0.04775769
# Iteration 171, loss = 0.04750078
# Iteration 172, loss = 0.04717044
# Iteration 173, loss = 0.04676743
# Iteration 174, loss = 0.04639354
# Iteration 175, loss = 0.04624428
# Iteration 176, loss = 0.04641368
# Iteration 177, loss = 0.04585707
# Iteration 178, loss = 0.04535089
# Iteration 179, loss = 0.04499453
# Iteration 180, loss = 0.04471001
# Iteration 181, loss = 0.04436189
# Iteration 182, loss = 0.04428541
# Iteration 183, loss = 0.04377925
# Iteration 184, loss = 0.04357533
# Iteration 185, loss = 0.04322456
# Iteration 186, loss = 0.04314919
# Iteration 187, loss = 0.04285434
# Iteration 188, loss = 0.04280406
# Iteration 189, loss = 0.04249933
# Iteration 190, loss = 0.04210841
# Iteration 191, loss = 0.04183107
# Iteration 192, loss = 0.04172324
# Iteration 193, loss = 0.04118810
# Iteration 194, loss = 0.04114050
# Iteration 195, loss = 0.04114727
# Iteration 196, loss = 0.04073856
# Iteration 197, loss = 0.04045654
# Iteration 198, loss = 0.04101163
# Iteration 199, loss = 0.03992195
# Iteration 200, loss = 0.04017321
# C:\Users\zuber\AppData\Roaming\Python\Python314\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='logistic', hidden_layer_sizes=(15,),
#               learning_rate_init=0.1, random_state=1, solver='sgd',
#               verbose=True)

# %%
fig, axes = plt.subplots(1, 1)
axes.plot(mlp.loss_curve_, 'o-')
axes.set_xlabel("number of iteration")
axes.set_ylabel("loss")
plt.show()

# %%
predictions = mlp.predict(x_test)
predictions[:50]
# Out:
# array([6, 9, 3, 7, 2, 1, 5, 2, 5, 2, 1, 9, 4, 0, 4, 2, 3, 7, 8, 8, 4, 3,
#        9, 7, 5, 6, 3, 5, 6, 3, 4, 9, 1, 4, 4, 6, 9, 4, 7, 6, 6, 9, 1, 3,
#        6, 1, 3, 0, 6, 5])

# %%
y_test[:50]
# Out:
# array([6, 9, 3, 7, 2, 1, 5, 2, 5, 2, 1, 9, 4, 0, 4, 2, 3, 7, 8, 8, 4, 3,
#        9, 7, 5, 6, 3, 5, 6, 3, 4, 9, 1, 4, 4, 6, 9, 4, 7, 6, 6, 9, 1, 3,
#        6, 1, 3, 0, 6, 5])

# %%
# importing the accuracy_score from the sklearn
from sklearn.metrics import accuracy_score

# calculating the accuracy with y_test and predictions
accuracy_score(y_test, predictions)
# Out:
# 0.975
